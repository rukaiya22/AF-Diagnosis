# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Check if GPU is available
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    print("GPU is available")
else:
    print("GPU is not available, using CPU")
# Out:
# GPU is available

# %%
tf.random.set_seed(42)  # For TensorFlow/Keras

# %% [markdown]
# #### checking duplication to ensure no duplicated items left

# %%
# # Use np.unique with axis=0 and return_inverse to identify duplicates
# _, idx, counts = np.unique(X, axis=0, return_index=True, return_counts=True)

# # Get duplicated rows
# duplicated_rows = X[np.isin(np.arange(X.shape[0]), idx[counts > 1])]

# print("Duplicated rows:")
# print(duplicated_rows)

# %%
# Set window size (124 time steps per sample)
window_size = 1240
data_name = "all"
dataset_number = 1
X_train = np.load(f'data/train_test_data/dataset_{dataset_number}_X_{data_name}_train_data.npy')
X_test = np.load(f'data/train_test_data/dataset_{dataset_number}_X_{data_name}_test_data.npy')

y_train = np.load(f'data/train_test_data/dataset_{dataset_number}_train_label.npy')
y_test = np.load(f'data/train_test_data/dataset_{dataset_number}_test_label.npy')

print("Train X shape:", X_train.shape)
print("Test X shape:", X_test.shape)
print("Train y shape:", y_train.shape)
print("Test y shape:", y_test.shape)
print(y_test)
# Out:
# Train X shape: (600, 1240, 3)
# Test X shape: (2400, 1240, 3)
# Train y shape: (600,)
# Test y shape: (2400,)
# [1 1 1 ... 1 1 1]

# %%
# Check if there are NaN or Inf values in the data
if np.any(np.isnan(X_train)) or np.any(np.isnan(y_train)):
    print("NaN values found in training data!")
if np.any(np.isinf(X_train)) or np.any(np.isinf(y_train)):
    print("Inf values found in training data!")

if np.any(np.isnan(X_test)) or np.any(np.isnan(y_test)):
    print("NaN values found in validation data!")
if np.any(np.isinf(X_test)) or np.any(np.isinf(y_test)):
    print("Inf values found in validation data!")

# %%
# Define the input shape (124 values, 1 feature per value)
input_shape = (window_size, 3)

# Build the Conv1D model (similar to AlexNet but adapted for 1D)
model = Sequential()

# 1st Conv1D layer
model.add(Conv1D(64, kernel_size=11, strides=1, activation='relu', input_shape=input_shape))
model.add(MaxPooling1D(pool_size=2, strides=2))

# 2nd Conv1D layer
model.add(Conv1D(128, kernel_size=5, strides=1, activation='relu'))
model.add(MaxPooling1D(pool_size=2, strides=2))

# 3rd Conv1D layer
model.add(Conv1D(256, kernel_size=3, strides=1, activation='relu'))
model.add(MaxPooling1D(pool_size=2, strides=2))

# Flatten the output from Conv1D layers
model.add(Flatten())

# Fully connected layers (Dense layers)
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))  # Dropout to prevent overfitting

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

# Output layer - assuming binary classification (adjust for your task)
model.add(Dense(1, activation='sigmoid'))  # For binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# /home/ruk/thesis/env/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_12 (Conv1D)              │ (None, 1230, 64)       │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_12 (MaxPooling1D) │ (None, 615, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 611, 128)       │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_13 (MaxPooling1D) │ (None, 305, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 303, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_14 (MaxPooling1D) │ (None, 151, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 38656)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1024)           │    39,584,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,251,905 (153.55 MB)
#  Trainable params: 40,251,905 (153.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    # optimizer = "adam", 
    loss = "binary_crossentropy", 
    metrics = ["accuracy"] 
)

# %%
# Set up EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=20,          # Wait for 3 epochs after the last improvement
    min_delta=0.0001,
    verbose=1,           # Print when early stopping is triggered
    restore_best_weights=True  # Restore the weights from the best epoch
)

# %%
training_desc = model.fit(
    X_train,
    y_train,
    batch_size = 50, 
    epochs= 1000, 
    validation_split =0.2, 
    shuffle = True, 
    callbacks=[early_stopping] 
)
# Out:
# Epoch 1/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 538ms/step - accuracy: 0.5996 - loss: 0.6734 - val_accuracy: 0.5833 - val_loss: 0.6761
# Epoch 2/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6263 - loss: 0.6754 - val_accuracy: 0.5750 - val_loss: 0.6318
# Epoch 3/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.6636 - loss: 0.6086 - val_accuracy: 0.5750 - val_loss: 0.6054
# Epoch 4/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6574 - loss: 0.5659 - val_accuracy: 0.6083 - val_loss: 0.6113
# Epoch 5/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.7276 - loss: 0.5292 - val_accuracy: 0.6167 - val_loss: 0.5980
# Epoch 6/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7351 - loss: 0.5118 - val_accuracy: 0.6500 - val_loss: 0.5838
# Epoch 7/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7433 - loss: 0.4866 - val_accuracy: 0.6667 - val_loss: 0.5660
# Epoch 8/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7254 - loss: 0.4725 - val_accuracy: 0.6500 - val_loss: 0.5474
# Epoch 9/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7558 - loss: 0.4389 - val_accuracy: 0.6500 - val_loss: 0.5266
# Epoch 10/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7932 - loss: 0.4220 - val_accuracy: 0.6833 - val_loss: 0.5359
# Epoch 11/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8044 - loss: 0.3970 - val_accuracy: 0.6500 - val_loss: 0.5174
# Epoch 12/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7940 - loss: 0.4026 - val_accuracy: 0.7583 - val_loss: 0.4807
# Epoch 13/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8355 - loss: 0.3638 - val_accuracy: 0.7917 - val_loss: 0.4383
# Epoch 14/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8574 - loss: 0.3155 - val_accuracy: 0.8417 - val_loss: 0.4020
# Epoch 15/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8996 - loss: 0.2768 - val_accuracy: 0.8083 - val_loss: 0.3497
# Epoch 16/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9026 - loss: 0.2524 - val_accuracy: 0.8167 - val_loss: 0.3613
# Epoch 17/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9055 - loss: 0.2331 - val_accuracy: 0.8167 - val_loss: 0.3762
# Epoch 18/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8979 - loss: 0.2259 - val_accuracy: 0.8000 - val_loss: 0.3704
# Epoch 19/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9152 - loss: 0.2090 - val_accuracy: 0.8750 - val_loss: 0.2747
# Epoch 20/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9418 - loss: 0.1751 - val_accuracy: 0.8833 - val_loss: 0.2613
# Epoch 21/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9571 - loss: 0.1391 - val_accuracy: 0.8750 - val_loss: 0.2683
# Epoch 22/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9639 - loss: 0.1266 - val_accuracy: 0.8667 - val_loss: 0.3257
# Epoch 23/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9619 - loss: 0.1076 - val_accuracy: 0.8833 - val_loss: 0.2454
# Epoch 24/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9777 - loss: 0.0952 - val_accuracy: 0.8833 - val_loss: 0.2187
# Epoch 25/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9847 - loss: 0.0852 - val_accuracy: 0.9083 - val_loss: 0.1952
# Epoch 26/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9938 - loss: 0.0622 - val_accuracy: 0.9083 - val_loss: 0.1877
# Epoch 27/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9904 - loss: 0.0588 - val_accuracy: 0.9250 - val_loss: 0.1648
# Epoch 28/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9936 - loss: 0.0514 - val_accuracy: 0.9083 - val_loss: 0.1858
# Epoch 29/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9900 - loss: 0.0524 - val_accuracy: 0.8917 - val_loss: 0.2699
# Epoch 30/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9900 - loss: 0.0413 - val_accuracy: 0.9167 - val_loss: 0.1910
# Epoch 31/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9968 - loss: 0.0342 - val_accuracy: 0.9083 - val_loss: 0.1851
# Epoch 32/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9960 - loss: 0.0305 - val_accuracy: 0.9333 - val_loss: 0.1459
# Epoch 33/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9992 - loss: 0.0257 - val_accuracy: 0.9333 - val_loss: 0.1328
# Epoch 34/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9983 - loss: 0.0216 - val_accuracy: 0.9083 - val_loss: 0.2313
# Epoch 35/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.9333 - val_loss: 0.1895
# Epoch 36/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9972 - loss: 0.0182 - val_accuracy: 0.9417 - val_loss: 0.1335
# Epoch 37/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.9333 - val_loss: 0.1506
# Epoch 38/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.9250 - val_loss: 0.1796
# Epoch 39/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.9250 - val_loss: 0.1612
# Epoch 40/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9333 - val_loss: 0.2090
# Epoch 41/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9333 - val_loss: 0.1733
# Epoch 42/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9333 - val_loss: 0.1759
# Epoch 43/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.9417 - val_loss: 0.1430
# Epoch 44/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9250 - val_loss: 0.2339
# Epoch 45/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9250 - val_loss: 0.1819
# Epoch 46/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9963 - loss: 0.0108 - val_accuracy: 0.9250 - val_loss: 0.2143
# Epoch 47/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9983 - loss: 0.0109 - val_accuracy: 0.9333 - val_loss: 0.1667
# Epoch 48/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9167 - val_loss: 0.2294
# Epoch 49/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9333 - val_loss: 0.2123
# Epoch 50/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9994 - loss: 0.0089 - val_accuracy: 0.9167 - val_loss: 0.2606
# Epoch 51/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9417 - val_loss: 0.1765
# Epoch 52/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9417 - val_loss: 0.1650
# Epoch 53/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9250 - val_loss: 0.1899
# Epoch 53: early stopping
# Restoring model weights from the end of the best epoch: 33.

# %%
from matplotlib import pyplot as plt
print(training_desc.history.keys())
# summarize history for accuracy
plt.plot(training_desc.history['accuracy'])
plt.plot(training_desc.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
# plt.savefig(f'results/figures/{data_name}-validation-accuracy.eps', format='eps')
plt.show()
# summarize history for loss
plt.plot(training_desc.history['loss'])
plt.plot(training_desc.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
# plt.savefig(f'results/figures/{data_name}-validation-loss.eps', format='eps')
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
dl_model_loss, dl_model_accuracy = model.evaluate(X_test,y_test,batch_size = 10)
print("loss: {}, accuracy: {}".format(dl_model_loss,dl_model_accuracy))
# Out:
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9511 - loss: 0.1536
# loss: 0.1528984159231186, accuracy: 0.9487500190734863

# %%
predictions = model.predict(X_test)

# Convert probabilities to binary predictions
binary_predictions = (predictions >= 0.5).astype(int)

# Flatten the array to 1D if needed
binary_predictions = binary_predictions.flatten()

# Create a DataFrame
result_df = pd.DataFrame(binary_predictions, columns=['Prediction'])

# Save to CSV
result_df.to_csv(f'results/{data_name}-dataset-{dataset_number}-predictions.csv', index=False)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
with open(f'results/{data_name}-dataset-{dataset_number}-accuracy.txt', 'w') as f: f.write(str(dl_model_accuracy))

# %%
# Set global font size and weight
plt.rcParams.update({
    'font.size': 16,  # Global font size for everything
    'font.weight': 'bold',  # Global font weight for everything
    'axes.titlesize': 20,  # Title font size
    'axes.titleweight': 'bold',  # Title font weight
    'axes.labelsize': 18,  # Axis labels font size
    'axes.labelweight': 'bold',  # Axis labels font weight
    'xtick.labelsize': 16,  # X-axis ticks font size
    'ytick.labelsize': 16,  # Y-axis ticks font size
    'legend.fontsize': 16  # Legend font size
})

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
pred_labels = model.predict(X_test)
cm = confusion_matrix(y_test, pred_labels.round())
cm_display = ConfusionMatrixDisplay(cm, display_labels=['Bad','Good'])
cm_display.plot()
cm_display.ax_.set(xlabel='Predicted)', ylabel='True')
plt.savefig(f'results/figures/{data_name}-dataset-{dataset_number}-confusion.eps', format='eps', bbox_inches='tight')
plt.show()
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Extracting values from the confusion matrix
TP = cm[1, 1]  # True Positives
TN = cm[0, 0]  # True Negatives
FP = cm[0, 1]  # False Positives
FN = cm[1, 0]  # False Negatives

# Compute metrics
TPR = TP / (TP + FN)  # True Positive Rate (Recall)
FPR = FP / (FP + TN)  # False Positive Rate
precision = TP / (TP + FP)  # Precision
recall = TPR  # Recall is the same as TPR
f1_score = 2 * (precision * recall) / (precision + recall)  # F1-Score

# Print the metrics
print("True Positive Rate (TPR) / Recall: ", TPR)
print("False Positive Rate (FPR): ", FPR)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-Score: ", f1_score)
# Out:
# True Positive Rate (TPR) / Recall:  0.9473684210526315
# False Positive Rate (FPR):  0.04953271028037383
# Precision:  0.9596344249809596
# Recall:  0.9473684210526315
# F1-Score:  0.9534619750283768

# %%
with open(f'results/{data_name}-dataset-{dataset_number}-metrics.txt', 'w') as f:
    f.write(f"Signal,accuracy,TPR,FPR,Precision,Recall,F1-Score\n")
    f.write(f"{data_name},{dl_model_accuracy},{TPR},{FPR},{precision},{recall},{f1_score}\n")
